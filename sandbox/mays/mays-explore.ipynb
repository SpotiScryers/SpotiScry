# %% [markdown]
# # Exploring Spotify API Dataset
# ## Setting up Notebook

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from scipy import stats

from prepare import prepare_df
from preprocessing import spotify_split

# %%
# Acquire the dataframe from our csv
df = pd.read_csv('full-playlist.csv', index_col=0)
df.head()
# Out:
#               artist                                  album release_date  \
# 0              Tay-K                                TRAPMAN   2020-07-12
# 1           Lil Wyte                           Doubt Me Now   2003-03-04
# 2            Kamelen                           KINGPIN SLIM   2019-11-29
# 3  Waka Flocka Flame                             Flockaveli   2010-10-01
# 4        Project Pat  Mista Don't Play: Everythangs Workin'   2001-02-13
#
#                              track_name                track_id  \
# 0                               TRAPMAN  6mecZbKK3JDeMdFRNxsCV5
# 1                            Oxy Cotton  5PtMwNq8Dp31uYdGGacVJE
# 2                   Kingpin O.G - Remix  6s8EhlBn2PIoESylkXnwYc
# 3    Grove St. Party (feat. Kebo Gotti)  2e9EZ2V5QGGZPMJacO3y0Y
# 4  Don't Save Her (feat. Crunchy Black)  3ZRd5Z0fiYtASLdEPPb16m
#
#    album_popularity                        label  danceability  energy   key  \
# 0                36                        Tay-K         0.792   0.594   2.0
# 1                55  Hypnotize Minds Productions         0.816   0.578   9.0
# 2                46                  NMG/G-HUSET         0.649   0.798   0.0
# 3                71        Asylum/Warner Records         0.705   0.702   0.0
# 4                55  Hypnotize Minds Productions         0.838   0.793  11.0
#
#    ...  valence    tempo  duration_ms  time_signature  explicit  popularity  \
# 0  ...    0.351   82.512     232803.0             4.0      True        43.0
# 1  ...    0.265  148.077     193920.0             4.0      True        61.0
# 2  ...    0.717  160.011     254390.0             4.0      True        23.0
# 3  ...    0.771  140.059     250493.0             4.0      True        62.0
# 4  ...    0.800  160.003     261933.0             4.0      True        45.0
#
#    disc_number  track_number                album_id  album_type
# 0          1.0           1.0  2J1hMj78HfdcMrmL2Sk6eR      single
# 1          1.0          11.0  2lwxcemR1muymEHNMblCpm       album
# 2          1.0          11.0  6va2RTYO2ois7t88RN0LhJ       album
# 3          1.0           9.0  6MQtWELG7aRX7CkAzQ6nLM       album
# 4          1.0           5.0  4QzaueQPQa0lqrMmQoh4v0       album
#
# [5 rows x 25 columns]

# %%
# Run the prepare_df function on the dataframe
df = prepare_df(df)
df
# Out:
#                                      artist  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                tay-k
# 5PtMwNq8Dp31uYdGGacVJE             lil wyte
# 6s8EhlBn2PIoESylkXnwYc              kamelen
# 2e9EZ2V5QGGZPMJacO3y0Y    waka flocka flame
# 3ZRd5Z0fiYtASLdEPPb16m          project pat
# ...                                     ...
# 5G9IXRzPaRJssJE76TDenY          tkay maidza
# 0g3zIOFTdkwgJdR48usYgY              beyoncé
# 75Z53FMCvlupjHfAh9XgDo             shenseea
# 7pXg4n5cOsZvMPsEtemNgz          sally sossa
# 2gVtrY8gCCynR9v0lyBL1m  tank and the bangas
#
#                                                            album release_date  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                                   trapman   2020-07-12
# 5PtMwNq8Dp31uYdGGacVJE                              doubt me now   2003-03-04
# 6s8EhlBn2PIoESylkXnwYc                              kingpin slim   2019-11-29
# 2e9EZ2V5QGGZPMJacO3y0Y                                flockaveli   2010-10-01
# 3ZRd5Z0fiYtASLdEPPb16m     mista don't play: everythangs workin'   2001-02-13
# ...                                                          ...          ...
# 5G9IXRzPaRJssJE76TDenY                                     shook   2020-05-12
# 0g3zIOFTdkwgJdR48usYgY  the lion king: the gift [deluxe edition]   2020-07-31
# 75Z53FMCvlupjHfAh9XgDo                        the sidechick song   2020-03-09
# 7pXg4n5cOsZvMPsEtemNgz                                 100 flows   2020-10-20
# 2gVtrY8gCCynR9v0lyBL1m                                 self care   2020-10-07
#
#                                                   track_name  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                               trapman
# 5PtMwNq8Dp31uYdGGacVJE                            oxy cotton
# 6s8EhlBn2PIoESylkXnwYc                   kingpin o.g - remix
# 2e9EZ2V5QGGZPMJacO3y0Y    grove st. party (feat. kebo gotti)
# 3ZRd5Z0fiYtASLdEPPb16m  don't save her (feat. crunchy black)
# ...                                                      ...
# 5G9IXRzPaRJssJE76TDenY                                 shook
# 0g3zIOFTdkwgJdR48usYgY                              my power
# 75Z53FMCvlupjHfAh9XgDo                    the sidechick song
# 7pXg4n5cOsZvMPsEtemNgz                             100 flows
# 2gVtrY8gCCynR9v0lyBL1m                             self care
#
#                         album_popularity                              label  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                36                              Tay-K
# 5PtMwNq8Dp31uYdGGacVJE                55        Hypnotize Minds Productions
# 6s8EhlBn2PIoESylkXnwYc                46                        NMG/G-HUSET
# 2e9EZ2V5QGGZPMJacO3y0Y                71              Asylum/Warner Records
# 3ZRd5Z0fiYtASLdEPPb16m                55        Hypnotize Minds Productions
# ...                                  ...                                ...
# 5G9IXRzPaRJssJE76TDenY                26                                4AD
# 0g3zIOFTdkwgJdR48usYgY                73    Parkwood Entertainment/Columbia
# 75Z53FMCvlupjHfAh9XgDo                45  Attomatic Records - Romeich Major
# 7pXg4n5cOsZvMPsEtemNgz                41                 LISTEN TO THE KIDS
# 2gVtrY8gCCynR9v0lyBL1m                35                              Verve
#
#                         danceability  energy  key  loudness  ...  disc_number  \
# track_id                                                     ...
# 6mecZbKK3JDeMdFRNxsCV5         0.792   0.594    2    -8.544  ...            1
# 5PtMwNq8Dp31uYdGGacVJE         0.816   0.578    9    -6.912  ...            1
# 6s8EhlBn2PIoESylkXnwYc         0.649   0.798    0    -6.450  ...            1
# 2e9EZ2V5QGGZPMJacO3y0Y         0.705   0.702    0    -4.783  ...            1
# 3ZRd5Z0fiYtASLdEPPb16m         0.838   0.793   11    -5.470  ...            1
# ...                              ...     ...  ...       ...  ...          ...
# 5G9IXRzPaRJssJE76TDenY         0.895   0.791    4    -4.581  ...            1
# 0g3zIOFTdkwgJdR48usYgY         0.769   0.856    7    -4.923  ...            1
# 75Z53FMCvlupjHfAh9XgDo         0.736   0.615    8    -4.716  ...            1
# 7pXg4n5cOsZvMPsEtemNgz         0.804   0.679    2    -5.910  ...            1
# 2gVtrY8gCCynR9v0lyBL1m         0.806   0.634    5    -6.201  ...            1
#
#                         track_number                album_id  album_type  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5             1  2J1hMj78HfdcMrmL2Sk6eR      single
# 5PtMwNq8Dp31uYdGGacVJE            11  2lwxcemR1muymEHNMblCpm       album
# 6s8EhlBn2PIoESylkXnwYc            11  6va2RTYO2ois7t88RN0LhJ       album
# 2e9EZ2V5QGGZPMJacO3y0Y             9  6MQtWELG7aRX7CkAzQ6nLM       album
# 3ZRd5Z0fiYtASLdEPPb16m             5  4QzaueQPQa0lqrMmQoh4v0       album
# ...                              ...                     ...         ...
# 5G9IXRzPaRJssJE76TDenY             1  5TUlKh4QEavBL1oilV4y86      single
# 0g3zIOFTdkwgJdR48usYgY            12  7kUuNU2LRmr9XbwLHXU9UZ       album
# 75Z53FMCvlupjHfAh9XgDo             1  0LUbxj9I4VJIVui4m2UGhC      single
# 7pXg4n5cOsZvMPsEtemNgz             1  7hbT17JOJUM2GbSgoI7wba      single
# 2gVtrY8gCCynR9v0lyBL1m             1  6Iur9pUGhyC4YdkmysT96v      single
#
#                         duration_seconds  duration_minutes  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5               232                 3
# 5PtMwNq8Dp31uYdGGacVJE               193                 3
# 6s8EhlBn2PIoESylkXnwYc               254                 4
# 2e9EZ2V5QGGZPMJacO3y0Y               250                 4
# 3ZRd5Z0fiYtASLdEPPb16m               261                 4
# ...                                  ...               ...
# 5G9IXRzPaRJssJE76TDenY               162                 2
# 0g3zIOFTdkwgJdR48usYgY               260                 4
# 75Z53FMCvlupjHfAh9XgDo               193                 3
# 7pXg4n5cOsZvMPsEtemNgz               162                 2
# 2gVtrY8gCCynR9v0lyBL1m               166                 2
#
#                         is_featured_artist  release_year  release_month  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                   0          2020             07
# 5PtMwNq8Dp31uYdGGacVJE                   0          2003             03
# 6s8EhlBn2PIoESylkXnwYc                   0          2019             11
# 2e9EZ2V5QGGZPMJacO3y0Y                   1          2010             10
# 3ZRd5Z0fiYtASLdEPPb16m                   1          2001             02
# ...                                    ...           ...            ...
# 5G9IXRzPaRJssJE76TDenY                   0          2020             05
# 0g3zIOFTdkwgJdR48usYgY                   0          2020             07
# 75Z53FMCvlupjHfAh9XgDo                   0          2020             03
# 7pXg4n5cOsZvMPsEtemNgz                   0          2020             10
# 2gVtrY8gCCynR9v0lyBL1m                   0          2020             10
#
#                         release_day
# track_id
# 6mecZbKK3JDeMdFRNxsCV5           12
# 5PtMwNq8Dp31uYdGGacVJE           04
# 6s8EhlBn2PIoESylkXnwYc           29
# 2e9EZ2V5QGGZPMJacO3y0Y           01
# 3ZRd5Z0fiYtASLdEPPb16m           13
# ...                             ...
# 5G9IXRzPaRJssJE76TDenY           12
# 0g3zIOFTdkwgJdR48usYgY           31
# 75Z53FMCvlupjHfAh9XgDo           09
# 7pXg4n5cOsZvMPsEtemNgz           20
# 2gVtrY8gCCynR9v0lyBL1m           07
#
# [5733 rows x 30 columns]

# %%
X_train, y_train, X_validate, y_validate, X_test, y_test, train, validate, test = spotify_split(df, 'popularity')
# Out:
# Shape of train: (4012, 29) | Shape of validate: (861, 29) | Shape of test: (860, 29)
# Percent train: 70.0        | Percent validate: 15.0       | Percent test: 15.0

# %%
train.head()
# Out:
#                                 artist                          album  \
# track_id
# 30bqVoKjX479ab90a8Pafp        lil peep                  star shopping
# 0HO8pCseEpgozNi3z0R4bc          father  who's gonna get fucked first?
# 643K3eEgRvdJiXjSzlz7dg          m.o.p.            first family 4 life
# 08EabdvPIHC4KBW7LfynPP     salt-n-pepa                 very necessary
# 6B2ZDVgJ0lHLgV9xC2PAJh  dungeon family               even in darkness
#
#                        release_date                         track_name  \
# track_id
# 30bqVoKjX479ab90a8Pafp   2019-04-19                      star shopping
# 0HO8pCseEpgozNi3z0R4bc   2015-03-17  everybody in the club gettin shot
# 643K3eEgRvdJiXjSzlz7dg   1998-08-11                 breakin' the rules
# 08EabdvPIHC4KBW7LfynPP   1993-10-12              no one does it better
# 6B2ZDVgJ0lHLgV9xC2PAJh   2001-10-22   white gutz (feat. bubba sparxxx)
#
#                         album_popularity               label  danceability  \
# track_id
# 30bqVoKjX479ab90a8Pafp                80            Lil Peep         0.585
# 0HO8pCseEpgozNi3z0R4bc                26       Awful Records         0.833
# 643K3eEgRvdJiXjSzlz7dg                36  Relativity Records         0.471
# 08EabdvPIHC4KBW7LfynPP                64     Mercury Records         0.874
# 6B2ZDVgJ0lHLgV9xC2PAJh                42              Arista         0.857
#
#                         energy  key  loudness  ...  disc_number  track_number  \
# track_id                                       ...
# 30bqVoKjX479ab90a8Pafp   0.471    4    -9.934  ...            1             1
# 0HO8pCseEpgozNi3z0R4bc   0.518   10   -10.126  ...            1            11
# 643K3eEgRvdJiXjSzlz7dg   0.671    1    -6.050  ...            1             2
# 08EabdvPIHC4KBW7LfynPP   0.507    6   -10.076  ...            1             2
# 6B2ZDVgJ0lHLgV9xC2PAJh   0.808    6    -5.468  ...            1             9
#
#                                       album_id  album_type  duration_seconds  \
# track_id
# 30bqVoKjX479ab90a8Pafp  1dEpGPZONvmwYlE2jDOWOM      single               142
# 0HO8pCseEpgozNi3z0R4bc  1ecx4skUBpk31GDJlMXi3X       album               120
# 643K3eEgRvdJiXjSzlz7dg  3kaX938EVrZuYE1JpNhZIW       album               252
# 08EabdvPIHC4KBW7LfynPP  2W2EmEpud13QHlhCFS9P8g       album               234
# 6B2ZDVgJ0lHLgV9xC2PAJh  2n4GKr0nKfFWoSTWZuNB9Z       album               266
#
#                         duration_minutes  is_featured_artist  release_year  \
# track_id
# 30bqVoKjX479ab90a8Pafp                 2                   0          2019
# 0HO8pCseEpgozNi3z0R4bc                 2                   0          2015
# 643K3eEgRvdJiXjSzlz7dg                 4                   0          1998
# 08EabdvPIHC4KBW7LfynPP                 3                   0          1993
# 6B2ZDVgJ0lHLgV9xC2PAJh                 4                   1          2001
#
#                         release_month  release_day
# track_id
# 30bqVoKjX479ab90a8Pafp             04           19
# 0HO8pCseEpgozNi3z0R4bc             03           17
# 643K3eEgRvdJiXjSzlz7dg             08           11
# 08EabdvPIHC4KBW7LfynPP             10           12
# 6B2ZDVgJ0lHLgV9xC2PAJh             10           22
#
# [5 rows x 30 columns]

# %%
train.popularity.mean()
# Out:
# 38.33150548354935

# %% [markdown]
# ## Exploring/Visualizing Label vs. Popularity

# %%
biggest_labels = train.groupby('label').popularity.agg(['mean', 'count']).sort_values(by=['count', 'mean'], ascending=False).head(20)
biggest_labels
# Out:
#                                   mean  count
# label
# Def Jam Recordings           43.257732     97
# Rockstarr Music Group         8.013889     72
# Columbia                     58.312500     64
# Atlantic Records             37.777778     63
# Atlantic Records/ATG         33.333333     57
# Nicki Minaj/Cash Money       44.185185     54
# 300 Entertainment            63.018868     53
# G59 Records, LLC             46.760000     50
# Universal Music Group         0.060000     50
# Sugar Trap                   40.391304     46
# RAL (Rush Associated Label)  35.227273     44
# Generation Now/Atlantic      63.609756     41
# Interscope                   37.918919     37
# Jive                         41.888889     36
# Republic Records             56.285714     35
# eOne Music                   15.771429     35
# M.A Music / 3D               41.393939     33
# The Orchard                  30.093750     32
# Hardcover/RCA Records        32.033333     30
# Polydor Records              23.586207     29

# %%
top_ten_labels = list(biggest_labels.sort_values(by='mean', ascending=False).head(10).index)
print(top_ten_labels)
print()
top_five_labels = list(biggest_labels.sort_values(by='mean', ascending=False).head(5).index)
print(top_five_labels)
# Out:
# ['Generation Now/Atlantic', '300 Entertainment', 'Columbia', 'Republic Records', 'Quality Control Music/Motown Records', 'G59 Records, LLC', 'Nicki Minaj/Cash Money', 'Def Jam Recordings', 'Jive', 'M.A Music / 3D']
#
# ['Generation Now/Atlantic', '300 Entertainment', 'Columbia', 'Republic Records', 'Quality Control Music/Motown Records']

# %%
pattern = '|'.join(top_ten_labels)
pattern2 = '|'.join(top_five_labels)

# %%
train['top_ten_label'] = train.label.str.contains(pattern)
train['top_five_label'] = train.label.str.contains(pattern2)
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
train['top_ten_label'] = train.top_ten_label.astype('int')
train['top_five_label'] = train.top_five_label.astype('int')
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
print(f'{train.top_ten_label.value_counts()}\n')

print(train.top_five_label.value_counts())
# Out:
# 0    3394
# 1     568
# Name: top_ten_label, dtype: int64
#
# 0    3675
# 1     287
# Name: top_five_label, dtype: int64

# %%
plt.figure(figsize=(12,10))
sns.barplot(x=train.top_ten_label, y=train.popularity)
plt.title('Avg popularity of tracks produced by top ten labels vs total avg', fontsize=20)
# Out:
# Text(0.5, 1.0, 'Avg popularity of tracks produced by top ten labels vs total avg')

# %%
df[df.label == 'Universal Music Group'].popularity.value_counts()
# Out:
# 0    65
# 1     3
# 2     1
# Name: popularity, dtype: int64

# %%
df[df.label == 'Rockstarr Music Group'].release_date.value_counts()
# Out:
# 2014-05-15    41
# 2014-05-12    20
# 2011-03-28    16
# 2018-10-19     7
# 2016-12-03     5
# Name: release_date, dtype: int64

# %%
train.duration_seconds.sort_values().head(58)
# Out:
# track_id
# 1lZWbmo1z6aSWEClUbljTq    13
# 5hFjdBt4CUJC5qC5AHiyzj    18
# 6pIXWGh8myeYOPJXUeMUrH    18
# 0SXZoLAD5MwbyYo4Puz2Te    19
# 0o95G9jx5D4MPepkPr4vEI    19
# 4IGcllu5ElkhYJD8gB5n5R    21
# 1BQYuDMFroaciJTvFt6Nkn    23
# 3BgwOI1jT8l6dFeAiESJVM    24
# 4XNF6h3MPEdBhlFkci0uZj    25
# 1fJmu2NuPZTUSBa1vyyWa6    29
# 53vTOt3KKo5JsE3f4Yjnde    30
# 1WPBD8Vw0LrG4nSxHNolEu    30
# 28R7qToaTp1JmIUqFBciGQ    33
# 6Op8OAAzNyCbsZ2nfCAMHq    36
# 3Zf9tk3vIX9UQmXtP10G2n    36
# 6jZKx1SYqVyIRELwJFWrJJ    36
# 58dsRKNbbcxQT3BywPdvpM    36
# 0YTwG0KfvR7JVkl54uBtqa    38
# 73tRJV1iPSaDO4QAvIJ8uf    38
# 6EmHzwlIqHdoeVFPuIDDNH    38
# 3POCBDGY3gn0OpW5KNaveD    40
# 4xXjH2OMjlkTWMZDKpAXP2    40
# 1opCPqNpNS8SonPLrWIbBy    41
# 7HgyP0n7pyJbMlyNBZ2qtF    41
# 20LhHCpjKNyatFAjDaxRAw    42
# 7Ekp79UXg1ZoN1RDeYvQyU    44
# 16fYuBwMogSAv2k6UhJG7H    44
# 2EdObJBynLrd4hzgcxEwu3    45
# 6myChYzeC1k2Crkn24uAQQ    45
# 6GgsO51ZpEuh0kLRy08YS3    46
# 7axSEVsXKAYNSvxh1R1mwy    47
# 6amlu3Zg4498QoPWYtuCRS    48
# 576E1IW36EtBWDS0H29V1X    48
# 1Znlc3UZAbSodFaMBjdpsX    48
# 3pxHcgYG8aKkclfWXBFSWv    49
# 27ifLNbJvjgnK8uSxksMJV    50
# 52cy98Qn8KidmYHyLevXiz    51
# 7ubzDBkeMcZhUesmGXO951    54
# 5byE3xnx2Mm3qKpbUjzCP3    54
# 3jsV09qJJjJ6bqfreonpFI    54
# 0CoxgiRdN5w3xHeNFRDhjc    55
# 5Revm2d7GCwYmo0RIlYjM3    56
# 0n6qoCWeQuMfSVDDOF1RSE    56
# 03Q441rd13kJnKBpR8vGdn    57
# 1VRI51Q60SzQjYXDg0Hesj    58
# 4lLdrM9fpLA1Pcng9WNMLp    58
# 3uX4ZoUyk5GACYjqteE4SY    58
# 0371uejvc5YvW30AtfNLCg    59
# 2PsjiKghYKF3k13NOIiFFW    60
# 0IShCbw4JJEpcmZiTwAena    60
# 4iFgO0Rmg5hXcPpM3RpayS    60
# 6pmoQSAU9y2EIz6ee2hBwc    60
# 4kTkoT7mNXTJ21WwFTIDxA    60
# 0WpDeBJ22LcwF4QoERQOTv    60
# 4x4cclsdcnzWphsjJzD4Bs    60
# 5Gnx5bNAglWcclJkuJnrys    60
# 1hXuODVWe5E3GEouSN9HtC    60
# 2qdpBHLf1e1ZxCajU1NGVs    60
# Name: duration_seconds, dtype: int64

# %%
train.groupby('top_five_label').popularity.mean()
# Out:
# top_five_label
# 0    37.303946
# 1    58.156794
# Name: popularity, dtype: float64

# %% [markdown]
# ### Hypothesis Test
# $H_0$: There is no difference in popularity between tracks released by the top 10 labels or not.
# $H_a$: Tracks released by the top 10 labels are more likely to be popular.
# alpha = .05

# %%
x1 = train[train.top_ten_label == 1].popularity
x2 = train[train.top_ten_label == 0].popularity
stats.ttest_ind(x1, x2)
# Out:
# Ttest_indResult(statistic=14.517071488259496, pvalue=1.4542768204991895e-46)

# %% [markdown]
# Our p value is lower than our alpha which means we can reject the null hypothesis and conclude that a song being produced by the top 10 labels is correlated with its popularity.

# %%
def get_top_ten_labels(df):
    biggest_labels = df.groupby('label').popularity.agg(['mean', 'count']).sort_values(by=['count', 'mean'], ascending=False).head(20)
    top_ten_labels = list(biggest_labels.sort_values(by='mean', ascending=False).head(10).index)
    pattern = '|'.join(top_ten_labels)
    df['top_ten_label'] = df.label.str.contains(pattern)
    df['top_ten_label'] = df.top_ten_label.astype('int')
    return df

# %%
train = get_top_ten_labels(train)

# %%
train.top_ten_label.value_counts()
# Out:
# 0    3429
# 1     583
# Name: top_ten_label, dtype: int64

# %% [markdown]
# ## Worst Labels vs Popularity

# %%
biggest_labels = train.groupby('label').popularity.agg(['mean', 'count']).sort_values(by=['count', 'mean'], ascending=False).head(20)
biggest_labels
# Out:
#                                            mean  count
# label
# Def Jam Recordings                    43.257732     97
# Rockstarr Music Group                  8.013889     72
# Columbia                              58.312500     64
# Atlantic Records                      37.777778     63
# Atlantic Records/ATG                  33.333333     57
# Nicki Minaj/Cash Money                44.185185     54
# 300 Entertainment                     63.018868     53
# G59 Records, LLC                      46.760000     50
# Sugar Trap                            40.391304     46
# RAL (Rush Associated Label)           35.227273     44
# Generation Now/Atlantic               63.609756     41
# Interscope                            37.918919     37
# Jive                                  41.888889     36
# Republic Records                      56.285714     35
# eOne Music                            15.771429     35
# M.A Music / 3D                        41.393939     33
# The Orchard                           30.093750     32
# Hardcover/RCA Records                 32.033333     30
# Polydor Records                       23.586207     29
# Quality Control Music/Motown Records  53.107143     28

# %%
worst_five_labels = list(biggest_labels.sort_values(by='mean').head(5).index)
worst_five_labels
# Out:
# ['Rockstarr Music Group',
#  'eOne Music',
#  'Polydor Records',
#  'The Orchard',
#  'Hardcover/RCA Records']

# %%
pattern = '|'.join(worst_five_labels)
train['worst_five_label'] = train.label.str.contains(pattern)
train['worst_five_label'] = train.worst_five_label.astype('int')
train.head()
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#                                 artist                          album  \
# track_id
# 30bqVoKjX479ab90a8Pafp        lil peep                  star shopping
# 0HO8pCseEpgozNi3z0R4bc          father  who's gonna get fucked first?
# 643K3eEgRvdJiXjSzlz7dg          m.o.p.            first family 4 life
# 08EabdvPIHC4KBW7LfynPP     salt-n-pepa                 very necessary
# 6B2ZDVgJ0lHLgV9xC2PAJh  dungeon family               even in darkness
#
#                        release_date                         track_name  \
# track_id
# 30bqVoKjX479ab90a8Pafp   2019-04-19                      star shopping
# 0HO8pCseEpgozNi3z0R4bc   2015-03-17  everybody in the club gettin shot
# 643K3eEgRvdJiXjSzlz7dg   1998-08-11                 breakin' the rules
# 08EabdvPIHC4KBW7LfynPP   1993-10-12              no one does it better
# 6B2ZDVgJ0lHLgV9xC2PAJh   2001-10-22   white gutz (feat. bubba sparxxx)
#
#                         album_popularity               label  danceability  \
# track_id
# 30bqVoKjX479ab90a8Pafp                80            Lil Peep         0.585
# 0HO8pCseEpgozNi3z0R4bc                26       Awful Records         0.833
# 643K3eEgRvdJiXjSzlz7dg                36  Relativity Records         0.471
# 08EabdvPIHC4KBW7LfynPP                64     Mercury Records         0.874
# 6B2ZDVgJ0lHLgV9xC2PAJh                42              Arista         0.857
#
#                         energy  key  loudness  ...  album_type  \
# track_id                                       ...
# 30bqVoKjX479ab90a8Pafp   0.471    4    -9.934  ...      single
# 0HO8pCseEpgozNi3z0R4bc   0.518   10   -10.126  ...       album
# 643K3eEgRvdJiXjSzlz7dg   0.671    1    -6.050  ...       album
# 08EabdvPIHC4KBW7LfynPP   0.507    6   -10.076  ...       album
# 6B2ZDVgJ0lHLgV9xC2PAJh   0.808    6    -5.468  ...       album
#
#                         duration_seconds  duration_minutes  \
# track_id
# 30bqVoKjX479ab90a8Pafp               142                 2
# 0HO8pCseEpgozNi3z0R4bc               120                 2
# 643K3eEgRvdJiXjSzlz7dg               252                 4
# 08EabdvPIHC4KBW7LfynPP               234                 3
# 6B2ZDVgJ0lHLgV9xC2PAJh               266                 4
#
#                         is_featured_artist  release_year  release_month  \
# track_id
# 30bqVoKjX479ab90a8Pafp                   0          2019             04
# 0HO8pCseEpgozNi3z0R4bc                   0          2015             03
# 643K3eEgRvdJiXjSzlz7dg                   0          1998             08
# 08EabdvPIHC4KBW7LfynPP                   0          1993             10
# 6B2ZDVgJ0lHLgV9xC2PAJh                   1          2001             10
#
#                         release_day  top_ten_label  worst_ten_label  \
# track_id
# 30bqVoKjX479ab90a8Pafp           19              0                0
# 0HO8pCseEpgozNi3z0R4bc           17              0                0
# 643K3eEgRvdJiXjSzlz7dg           11              0                0
# 08EabdvPIHC4KBW7LfynPP           12              0                0
# 6B2ZDVgJ0lHLgV9xC2PAJh           22              0                0
#
#                         worst_five_label
# track_id
# 30bqVoKjX479ab90a8Pafp                 0
# 0HO8pCseEpgozNi3z0R4bc                 0
# 643K3eEgRvdJiXjSzlz7dg                 0
# 08EabdvPIHC4KBW7LfynPP                 0
# 6B2ZDVgJ0lHLgV9xC2PAJh                 0
#
# [5 rows x 33 columns]

# %%
train.worst_ten_label.value_counts()
# Out:
# 0    3459
# 1     503
# Name: worst_ten_label, dtype: int64

# %%
train.groupby('worst_five_label').popularity.mean()
# Out:
# worst_five_label
# 0    39.873206
# 1    18.900000
# Name: popularity, dtype: float64

# %% [markdown]
# ### Hypothesis Test  2
# $H_0$: There is no difference in popularity between tracks released by the worst 5 labels or not.
# $H_a$: Tracks released by the worst 5 labels are more likely to be unpopular.
# alpha = .05

# %%
x1 = train[train.worst_five_label == 1].popularity
x2 = train[train.worst_five_label == 0].popularity
stats.ttest_ind(x1, x2)
# Out:
# Ttest_indResult(statistic=-13.03889168931012, pvalue=4.4259414799537905e-38)

# %%
def get_labels_features(df):
    biggest_labels = df.groupby('label').popularity.agg(['mean', 'count']).sort_values(by=['count', 'mean'], ascending=False).head(20)
    top_ten_labels = list(biggest_labels.sort_values(by='mean', ascending=False).head(10).index)
    top_five_labels = list(biggest_labels.sort_values(by='mean', ascending=False).head(5).index)
    worst_ten_labels = list(biggest_labels.sort_values(by='mean').head(10).index)
    worst_five_labels = list(biggest_labels.sort_values(by='mean').head(5).index)
    pattern1 = '|'.join(top_ten_labels)
    pattern2 = '|'.join(top_ten_labels)
    pattern3 = '|'.join(top_ten_labels)
    pattern4 = '|'.join(top_ten_labels)
    df['top_ten_label'] = df.label.str.contains(pattern1)
    df['top_five_label'] = df.label.str.contains(pattern1)
    df['worst_ten_label'] = df.label.str.contains(pattern1)
    df['worst_five_label'] = df.label.str.contains(pattern1)
    df['top_ten_label'] = df.top_ten_label.astype('int')
    df['top_five_label'] = df.top_five_label.astype('int')
    df['worst_ten_label'] = df.worst_ten_label.astype('int')
    df['worst_five_label'] = df.worst_five_label.astype('int')
    return df

# %%
train = get_labels_features(train)
train
# Out:
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   from ipykernel import kernelapp as app
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   app.launch_new_instance()
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /usr/local/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#                                 artist  \
# track_id
# 30bqVoKjX479ab90a8Pafp        lil peep
# 0HO8pCseEpgozNi3z0R4bc          father
# 643K3eEgRvdJiXjSzlz7dg          m.o.p.
# 08EabdvPIHC4KBW7LfynPP     salt-n-pepa
# 6B2ZDVgJ0lHLgV9xC2PAJh  dungeon family
# ...                                ...
# 6Hf3lTdh7gNQO3GoVw9CEM     bree runway
# 1HnYtO4YEAMf98bu3hiYNA      nadia rose
# 0IShCbw4JJEpcmZiTwAena    tierra whack
# 6YDNFOpoNzP8sNgbcOSXsG   missy elliott
# 70CYAL35X3T73qVStJNpZ2     nicki minaj
#
#                                                                 album  \
# track_id
# 30bqVoKjX479ab90a8Pafp                                  star shopping
# 0HO8pCseEpgozNi3z0R4bc                  who's gonna get fucked first?
# 643K3eEgRvdJiXjSzlz7dg                            first family 4 life
# 08EabdvPIHC4KBW7LfynPP                                 very necessary
# 6B2ZDVgJ0lHLgV9xC2PAJh                               even in darkness
# ...                                                               ...
# 6Hf3lTdh7gNQO3GoVw9CEM                                    2000and4eva
# 1HnYtO4YEAMf98bu3hiYNA                               highly flammable
# 0IShCbw4JJEpcmZiTwAena                                    whack world
# 6YDNFOpoNzP8sNgbcOSXsG                         miss e... so addictive
# 70CYAL35X3T73qVStJNpZ2  the pinkprint (international deluxe explicit)
#
#                        release_date                         track_name  \
# track_id
# 30bqVoKjX479ab90a8Pafp   2019-04-19                      star shopping
# 0HO8pCseEpgozNi3z0R4bc   2015-03-17  everybody in the club gettin shot
# 643K3eEgRvdJiXjSzlz7dg   1998-08-11                 breakin' the rules
# 08EabdvPIHC4KBW7LfynPP   1993-10-12              no one does it better
# 6B2ZDVgJ0lHLgV9xC2PAJh   2001-10-22   white gutz (feat. bubba sparxxx)
# ...                             ...                                ...
# 6Hf3lTdh7gNQO3GoVw9CEM   2020-11-06                       little nokia
# 1HnYtO4YEAMf98bu3hiYNA   2017-01-13          poltergeist (feat. alika)
# 0IShCbw4JJEpcmZiTwAena   2018-05-30                          dr. seuss
# 6YDNFOpoNzP8sNgbcOSXsG   2001-05-14                      higher ground
# 70CYAL35X3T73qVStJNpZ2   2014-12-15                        grand piano
#
#                         album_popularity                   label  \
# track_id
# 30bqVoKjX479ab90a8Pafp                80                Lil Peep
# 0HO8pCseEpgozNi3z0R4bc                26           Awful Records
# 643K3eEgRvdJiXjSzlz7dg                36      Relativity Records
# 08EabdvPIHC4KBW7LfynPP                64         Mercury Records
# 6B2ZDVgJ0lHLgV9xC2PAJh                42                  Arista
# ...                                  ...                     ...
# 6Hf3lTdh7gNQO3GoVw9CEM                54                     EMI
# 1HnYtO4YEAMf98bu3hiYNA                38      Relentless Records
# 0IShCbw4JJEpcmZiTwAena                64            Tierra Whack
# 6YDNFOpoNzP8sNgbcOSXsG                64    Atlantic Records/ATG
# 70CYAL35X3T73qVStJNpZ2                72  Nicki Minaj/Cash Money
#
#                         danceability  energy  key  loudness  ...  \
# track_id                                                     ...
# 30bqVoKjX479ab90a8Pafp         0.585   0.471    4    -9.934  ...
# 0HO8pCseEpgozNi3z0R4bc         0.833   0.518   10   -10.126  ...
# 643K3eEgRvdJiXjSzlz7dg         0.471   0.671    1    -6.050  ...
# 08EabdvPIHC4KBW7LfynPP         0.874   0.507    6   -10.076  ...
# 6B2ZDVgJ0lHLgV9xC2PAJh         0.857   0.808    6    -5.468  ...
# ...                              ...     ...  ...       ...  ...
# 6Hf3lTdh7gNQO3GoVw9CEM         0.708   0.578   11    -4.355  ...
# 1HnYtO4YEAMf98bu3hiYNA         0.457   0.454    9   -10.185  ...
# 0IShCbw4JJEpcmZiTwAena         0.793   0.605    1    -9.781  ...
# 6YDNFOpoNzP8sNgbcOSXsG         0.761   0.469    7    -7.895  ...
# 70CYAL35X3T73qVStJNpZ2         0.330   0.210    4   -10.808  ...
#
#                         duration_seconds  duration_minutes  \
# track_id
# 30bqVoKjX479ab90a8Pafp               142                 2
# 0HO8pCseEpgozNi3z0R4bc               120                 2
# 643K3eEgRvdJiXjSzlz7dg               252                 4
# 08EabdvPIHC4KBW7LfynPP               234                 3
# 6B2ZDVgJ0lHLgV9xC2PAJh               266                 4
# ...                                  ...               ...
# 6Hf3lTdh7gNQO3GoVw9CEM               139                 2
# 1HnYtO4YEAMf98bu3hiYNA               237                 3
# 0IShCbw4JJEpcmZiTwAena                60                 1
# 6YDNFOpoNzP8sNgbcOSXsG               106                 1
# 70CYAL35X3T73qVStJNpZ2               259                 4
#
#                         is_featured_artist  release_year  release_month  \
# track_id
# 30bqVoKjX479ab90a8Pafp                   0          2019             04
# 0HO8pCseEpgozNi3z0R4bc                   0          2015             03
# 643K3eEgRvdJiXjSzlz7dg                   0          1998             08
# 08EabdvPIHC4KBW7LfynPP                   0          1993             10
# 6B2ZDVgJ0lHLgV9xC2PAJh                   1          2001             10
# ...                                    ...           ...            ...
# 6Hf3lTdh7gNQO3GoVw9CEM                   0          2020             11
# 1HnYtO4YEAMf98bu3hiYNA                   1          2017             01
# 0IShCbw4JJEpcmZiTwAena                   0          2018             05
# 6YDNFOpoNzP8sNgbcOSXsG                   0          2001             05
# 70CYAL35X3T73qVStJNpZ2                   0          2014             12
#
#                         release_day  top_ten_label  top_five_label  \
# track_id
# 30bqVoKjX479ab90a8Pafp           19              0               0
# 0HO8pCseEpgozNi3z0R4bc           17              0               0
# 643K3eEgRvdJiXjSzlz7dg           11              0               0
# 08EabdvPIHC4KBW7LfynPP           12              0               0
# 6B2ZDVgJ0lHLgV9xC2PAJh           22              0               0
# ...                             ...            ...             ...
# 6Hf3lTdh7gNQO3GoVw9CEM           06              0               0
# 1HnYtO4YEAMf98bu3hiYNA           13              0               0
# 0IShCbw4JJEpcmZiTwAena           30              0               0
# 6YDNFOpoNzP8sNgbcOSXsG           14              0               0
# 70CYAL35X3T73qVStJNpZ2           15              1               1
#
#                         worst_ten_label  worst_five_label
# track_id
# 30bqVoKjX479ab90a8Pafp                0                 0
# 0HO8pCseEpgozNi3z0R4bc                0                 0
# 643K3eEgRvdJiXjSzlz7dg                0                 0
# 08EabdvPIHC4KBW7LfynPP                0                 0
# 6B2ZDVgJ0lHLgV9xC2PAJh                0                 0
# ...                                 ...               ...
# 6Hf3lTdh7gNQO3GoVw9CEM                0                 0
# 1HnYtO4YEAMf98bu3hiYNA                0                 0
# 0IShCbw4JJEpcmZiTwAena                0                 0
# 6YDNFOpoNzP8sNgbcOSXsG                0                 0
# 70CYAL35X3T73qVStJNpZ2                1                 1
#
# [3962 rows x 34 columns]

# %%
del train['top_ten_label']
del train['top_five_label']
del train['worst_ten_label']
del train['worst_five_label']

# %%
df
# Out:
#                                      artist  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                tay-k
# 5PtMwNq8Dp31uYdGGacVJE             lil wyte
# 6s8EhlBn2PIoESylkXnwYc              kamelen
# 2e9EZ2V5QGGZPMJacO3y0Y    waka flocka flame
# 3ZRd5Z0fiYtASLdEPPb16m          project pat
# ...                                     ...
# 5G9IXRzPaRJssJE76TDenY          tkay maidza
# 0g3zIOFTdkwgJdR48usYgY              beyoncé
# 75Z53FMCvlupjHfAh9XgDo             shenseea
# 7pXg4n5cOsZvMPsEtemNgz          sally sossa
# 2gVtrY8gCCynR9v0lyBL1m  tank and the bangas
#
#                                                            album release_date  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                                   trapman   2020-07-12
# 5PtMwNq8Dp31uYdGGacVJE                              doubt me now   2003-03-04
# 6s8EhlBn2PIoESylkXnwYc                              kingpin slim   2019-11-29
# 2e9EZ2V5QGGZPMJacO3y0Y                                flockaveli   2010-10-01
# 3ZRd5Z0fiYtASLdEPPb16m     mista don't play: everythangs workin'   2001-02-13
# ...                                                          ...          ...
# 5G9IXRzPaRJssJE76TDenY                                     shook   2020-05-12
# 0g3zIOFTdkwgJdR48usYgY  the lion king: the gift [deluxe edition]   2020-07-31
# 75Z53FMCvlupjHfAh9XgDo                        the sidechick song   2020-03-09
# 7pXg4n5cOsZvMPsEtemNgz                                 100 flows   2020-10-20
# 2gVtrY8gCCynR9v0lyBL1m                                 self care   2020-10-07
#
#                                                   track_name  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                               trapman
# 5PtMwNq8Dp31uYdGGacVJE                            oxy cotton
# 6s8EhlBn2PIoESylkXnwYc                   kingpin o.g - remix
# 2e9EZ2V5QGGZPMJacO3y0Y    grove st. party (feat. kebo gotti)
# 3ZRd5Z0fiYtASLdEPPb16m  don't save her (feat. crunchy black)
# ...                                                      ...
# 5G9IXRzPaRJssJE76TDenY                                 shook
# 0g3zIOFTdkwgJdR48usYgY                              my power
# 75Z53FMCvlupjHfAh9XgDo                    the sidechick song
# 7pXg4n5cOsZvMPsEtemNgz                             100 flows
# 2gVtrY8gCCynR9v0lyBL1m                             self care
#
#                         album_popularity                              label  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                36                              Tay-K
# 5PtMwNq8Dp31uYdGGacVJE                55        Hypnotize Minds Productions
# 6s8EhlBn2PIoESylkXnwYc                46                        NMG/G-HUSET
# 2e9EZ2V5QGGZPMJacO3y0Y                71              Asylum/Warner Records
# 3ZRd5Z0fiYtASLdEPPb16m                55        Hypnotize Minds Productions
# ...                                  ...                                ...
# 5G9IXRzPaRJssJE76TDenY                26                                4AD
# 0g3zIOFTdkwgJdR48usYgY                73    Parkwood Entertainment/Columbia
# 75Z53FMCvlupjHfAh9XgDo                45  Attomatic Records - Romeich Major
# 7pXg4n5cOsZvMPsEtemNgz                41                 LISTEN TO THE KIDS
# 2gVtrY8gCCynR9v0lyBL1m                35                              Verve
#
#                         danceability  energy  key  loudness  ...  \
# track_id                                                     ...
# 6mecZbKK3JDeMdFRNxsCV5         0.792   0.594    2    -8.544  ...
# 5PtMwNq8Dp31uYdGGacVJE         0.816   0.578    9    -6.912  ...
# 6s8EhlBn2PIoESylkXnwYc         0.649   0.798    0    -6.450  ...
# 2e9EZ2V5QGGZPMJacO3y0Y         0.705   0.702    0    -4.783  ...
# 3ZRd5Z0fiYtASLdEPPb16m         0.838   0.793   11    -5.470  ...
# ...                              ...     ...  ...       ...  ...
# 5G9IXRzPaRJssJE76TDenY         0.895   0.791    4    -4.581  ...
# 0g3zIOFTdkwgJdR48usYgY         0.769   0.856    7    -4.923  ...
# 75Z53FMCvlupjHfAh9XgDo         0.736   0.615    8    -4.716  ...
# 7pXg4n5cOsZvMPsEtemNgz         0.804   0.679    2    -5.910  ...
# 2gVtrY8gCCynR9v0lyBL1m         0.806   0.634    5    -6.201  ...
#
#                         track_number                album_id  album_type  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5             1  2J1hMj78HfdcMrmL2Sk6eR      single
# 5PtMwNq8Dp31uYdGGacVJE            11  2lwxcemR1muymEHNMblCpm       album
# 6s8EhlBn2PIoESylkXnwYc            11  6va2RTYO2ois7t88RN0LhJ       album
# 2e9EZ2V5QGGZPMJacO3y0Y             9  6MQtWELG7aRX7CkAzQ6nLM       album
# 3ZRd5Z0fiYtASLdEPPb16m             5  4QzaueQPQa0lqrMmQoh4v0       album
# ...                              ...                     ...         ...
# 5G9IXRzPaRJssJE76TDenY             1  5TUlKh4QEavBL1oilV4y86      single
# 0g3zIOFTdkwgJdR48usYgY            12  7kUuNU2LRmr9XbwLHXU9UZ       album
# 75Z53FMCvlupjHfAh9XgDo             1  0LUbxj9I4VJIVui4m2UGhC      single
# 7pXg4n5cOsZvMPsEtemNgz             1  7hbT17JOJUM2GbSgoI7wba      single
# 2gVtrY8gCCynR9v0lyBL1m             1  6Iur9pUGhyC4YdkmysT96v      single
#
#                         duration_seconds  duration_minutes  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5               232                 3
# 5PtMwNq8Dp31uYdGGacVJE               193                 3
# 6s8EhlBn2PIoESylkXnwYc               254                 4
# 2e9EZ2V5QGGZPMJacO3y0Y               250                 4
# 3ZRd5Z0fiYtASLdEPPb16m               261                 4
# ...                                  ...               ...
# 5G9IXRzPaRJssJE76TDenY               162                 2
# 0g3zIOFTdkwgJdR48usYgY               260                 4
# 75Z53FMCvlupjHfAh9XgDo               193                 3
# 7pXg4n5cOsZvMPsEtemNgz               162                 2
# 2gVtrY8gCCynR9v0lyBL1m               166                 2
#
#                         is_featured_artist  release_year  release_month  \
# track_id
# 6mecZbKK3JDeMdFRNxsCV5                   0          2020             07
# 5PtMwNq8Dp31uYdGGacVJE                   0          2003             03
# 6s8EhlBn2PIoESylkXnwYc                   0          2019             11
# 2e9EZ2V5QGGZPMJacO3y0Y                   1          2010             10
# 3ZRd5Z0fiYtASLdEPPb16m                   1          2001             02
# ...                                    ...           ...            ...
# 5G9IXRzPaRJssJE76TDenY                   0          2020             05
# 0g3zIOFTdkwgJdR48usYgY                   0          2020             07
# 75Z53FMCvlupjHfAh9XgDo                   0          2020             03
# 7pXg4n5cOsZvMPsEtemNgz                   0          2020             10
# 2gVtrY8gCCynR9v0lyBL1m                   0          2020             10
#
#                         release_day   popularity_bin
# track_id
# 6mecZbKK3JDeMdFRNxsCV5           12         Moderate
# 5PtMwNq8Dp31uYdGGacVJE           04             High
# 6s8EhlBn2PIoESylkXnwYc           29   Moderately Low
# 2e9EZ2V5QGGZPMJacO3y0Y           01             High
# 3ZRd5Z0fiYtASLdEPPb16m           13         Moderate
# ...                             ...              ...
# 5G9IXRzPaRJssJE76TDenY           12   Moderately Low
# 0g3zIOFTdkwgJdR48usYgY           31             High
# 75Z53FMCvlupjHfAh9XgDo           09  Moderately High
# 7pXg4n5cOsZvMPsEtemNgz           20  Moderately High
# 2gVtrY8gCCynR9v0lyBL1m           07         Moderate
#
# [5733 rows x 31 columns]

# %%
train
# Out:
#                                 artist  \
# track_id
# 30bqVoKjX479ab90a8Pafp        lil peep
# 0HO8pCseEpgozNi3z0R4bc          father
# 643K3eEgRvdJiXjSzlz7dg          m.o.p.
# 08EabdvPIHC4KBW7LfynPP     salt-n-pepa
# 6B2ZDVgJ0lHLgV9xC2PAJh  dungeon family
# ...                                ...
# 6Hf3lTdh7gNQO3GoVw9CEM     bree runway
# 1HnYtO4YEAMf98bu3hiYNA      nadia rose
# 0IShCbw4JJEpcmZiTwAena    tierra whack
# 6YDNFOpoNzP8sNgbcOSXsG   missy elliott
# 70CYAL35X3T73qVStJNpZ2     nicki minaj
#
#                                                                 album  \
# track_id
# 30bqVoKjX479ab90a8Pafp                                  star shopping
# 0HO8pCseEpgozNi3z0R4bc                  who's gonna get fucked first?
# 643K3eEgRvdJiXjSzlz7dg                            first family 4 life
# 08EabdvPIHC4KBW7LfynPP                                 very necessary
# 6B2ZDVgJ0lHLgV9xC2PAJh                               even in darkness
# ...                                                               ...
# 6Hf3lTdh7gNQO3GoVw9CEM                                    2000and4eva
# 1HnYtO4YEAMf98bu3hiYNA                               highly flammable
# 0IShCbw4JJEpcmZiTwAena                                    whack world
# 6YDNFOpoNzP8sNgbcOSXsG                         miss e... so addictive
# 70CYAL35X3T73qVStJNpZ2  the pinkprint (international deluxe explicit)
#
#                        release_date                         track_name  \
# track_id
# 30bqVoKjX479ab90a8Pafp   2019-04-19                      star shopping
# 0HO8pCseEpgozNi3z0R4bc   2015-03-17  everybody in the club gettin shot
# 643K3eEgRvdJiXjSzlz7dg   1998-08-11                 breakin' the rules
# 08EabdvPIHC4KBW7LfynPP   1993-10-12              no one does it better
# 6B2ZDVgJ0lHLgV9xC2PAJh   2001-10-22   white gutz (feat. bubba sparxxx)
# ...                             ...                                ...
# 6Hf3lTdh7gNQO3GoVw9CEM   2020-11-06                       little nokia
# 1HnYtO4YEAMf98bu3hiYNA   2017-01-13          poltergeist (feat. alika)
# 0IShCbw4JJEpcmZiTwAena   2018-05-30                          dr. seuss
# 6YDNFOpoNzP8sNgbcOSXsG   2001-05-14                      higher ground
# 70CYAL35X3T73qVStJNpZ2   2014-12-15                        grand piano
#
#                         album_popularity                   label  \
# track_id
# 30bqVoKjX479ab90a8Pafp                80                Lil Peep
# 0HO8pCseEpgozNi3z0R4bc                26           Awful Records
# 643K3eEgRvdJiXjSzlz7dg                36      Relativity Records
# 08EabdvPIHC4KBW7LfynPP                64         Mercury Records
# 6B2ZDVgJ0lHLgV9xC2PAJh                42                  Arista
# ...                                  ...                     ...
# 6Hf3lTdh7gNQO3GoVw9CEM                54                     EMI
# 1HnYtO4YEAMf98bu3hiYNA                38      Relentless Records
# 0IShCbw4JJEpcmZiTwAena                64            Tierra Whack
# 6YDNFOpoNzP8sNgbcOSXsG                64    Atlantic Records/ATG
# 70CYAL35X3T73qVStJNpZ2                72  Nicki Minaj/Cash Money
#
#                         danceability  energy  key  loudness  ...  disc_number  \
# track_id                                                     ...
# 30bqVoKjX479ab90a8Pafp         0.585   0.471    4    -9.934  ...            1
# 0HO8pCseEpgozNi3z0R4bc         0.833   0.518   10   -10.126  ...            1
# 643K3eEgRvdJiXjSzlz7dg         0.471   0.671    1    -6.050  ...            1
# 08EabdvPIHC4KBW7LfynPP         0.874   0.507    6   -10.076  ...            1
# 6B2ZDVgJ0lHLgV9xC2PAJh         0.857   0.808    6    -5.468  ...            1
# ...                              ...     ...  ...       ...  ...          ...
# 6Hf3lTdh7gNQO3GoVw9CEM         0.708   0.578   11    -4.355  ...            1
# 1HnYtO4YEAMf98bu3hiYNA         0.457   0.454    9   -10.185  ...            1
# 0IShCbw4JJEpcmZiTwAena         0.793   0.605    1    -9.781  ...            1
# 6YDNFOpoNzP8sNgbcOSXsG         0.761   0.469    7    -7.895  ...            1
# 70CYAL35X3T73qVStJNpZ2         0.330   0.210    4   -10.808  ...            1
#
#                         track_number                album_id  album_type  \
# track_id
# 30bqVoKjX479ab90a8Pafp             1  1dEpGPZONvmwYlE2jDOWOM      single
# 0HO8pCseEpgozNi3z0R4bc            11  1ecx4skUBpk31GDJlMXi3X       album
# 643K3eEgRvdJiXjSzlz7dg             2  3kaX938EVrZuYE1JpNhZIW       album
# 08EabdvPIHC4KBW7LfynPP             2  2W2EmEpud13QHlhCFS9P8g       album
# 6B2ZDVgJ0lHLgV9xC2PAJh             9  2n4GKr0nKfFWoSTWZuNB9Z       album
# ...                              ...                     ...         ...
# 6Hf3lTdh7gNQO3GoVw9CEM             2  4lmOcEBG9fJjc6UeMbttVt       album
# 1HnYtO4YEAMf98bu3hiYNA             7  3rPYGgkKveNxWMGRUKtC00       album
# 0IShCbw4JJEpcmZiTwAena            14  3ogNAkUhvQy0cFOfLoR6Y8       album
# 6YDNFOpoNzP8sNgbcOSXsG            17  20t54K6C80QQH7vbcpfJcP       album
# 70CYAL35X3T73qVStJNpZ2            16  40XGTQ7FN6Y3dZXJhKBe96       album
#
#                         duration_seconds  duration_minutes  \
# track_id
# 30bqVoKjX479ab90a8Pafp               142                 2
# 0HO8pCseEpgozNi3z0R4bc               120                 2
# 643K3eEgRvdJiXjSzlz7dg               252                 4
# 08EabdvPIHC4KBW7LfynPP               234                 3
# 6B2ZDVgJ0lHLgV9xC2PAJh               266                 4
# ...                                  ...               ...
# 6Hf3lTdh7gNQO3GoVw9CEM               139                 2
# 1HnYtO4YEAMf98bu3hiYNA               237                 3
# 0IShCbw4JJEpcmZiTwAena                60                 1
# 6YDNFOpoNzP8sNgbcOSXsG               106                 1
# 70CYAL35X3T73qVStJNpZ2               259                 4
#
#                         is_featured_artist  release_year  release_month  \
# track_id
# 30bqVoKjX479ab90a8Pafp                   0          2019             04
# 0HO8pCseEpgozNi3z0R4bc                   0          2015             03
# 643K3eEgRvdJiXjSzlz7dg                   0          1998             08
# 08EabdvPIHC4KBW7LfynPP                   0          1993             10
# 6B2ZDVgJ0lHLgV9xC2PAJh                   1          2001             10
# ...                                    ...           ...            ...
# 6Hf3lTdh7gNQO3GoVw9CEM                   0          2020             11
# 1HnYtO4YEAMf98bu3hiYNA                   1          2017             01
# 0IShCbw4JJEpcmZiTwAena                   0          2018             05
# 6YDNFOpoNzP8sNgbcOSXsG                   0          2001             05
# 70CYAL35X3T73qVStJNpZ2                   0          2014             12
#
#                         release_day
# track_id
# 30bqVoKjX479ab90a8Pafp           19
# 0HO8pCseEpgozNi3z0R4bc           17
# 643K3eEgRvdJiXjSzlz7dg           11
# 08EabdvPIHC4KBW7LfynPP           12
# 6B2ZDVgJ0lHLgV9xC2PAJh           22
# ...                             ...
# 6Hf3lTdh7gNQO3GoVw9CEM           06
# 1HnYtO4YEAMf98bu3hiYNA           13
# 0IShCbw4JJEpcmZiTwAena           30
# 6YDNFOpoNzP8sNgbcOSXsG           14
# 70CYAL35X3T73qVStJNpZ2           15
#
# [3962 rows x 30 columns]

# %% [markdown]
# ~~~
# cid = YOURCLIENTID
# c_secret = YOURCLIENTSECRET
# ~~~
